# %% [markdown]
# ##  Functions

# %% [markdown]
# - A reusable piece of code

# %% [markdown]
# - We define a function using the def reserved word

# %% [markdown]
# - A function is some reusable code that takes arguements as inputs,does some compuation and then returns a result/results.

# %% [markdown]
# ## DEF- Defined Function

# %% [markdown]
# e.g

# %%
big = max('Hello world')
print(big)
# Out:
# w

# %%
tiny = min('Hello world')
print(tiny)

# %% [markdown]
# ## . Two types of functions

# %% [markdown]
# ## (a) Built in functions

# %% [markdown]
# They are provided as part of python functions.i.e they came with python

# %% [markdown]
# e.g  print(),input(),type(),float(),int()

# %% [markdown]
# ## (b) User defined functions

# %%
Functions one define by his or her self

# %% [markdown]
# ## Type conversions

# %%
i= 42

# %%
type(i)
# Out:
# int

# %%
f = float(i)
print(f)
# Out:
# 42.0

# %%
type(f)
# Out:
# float

# %%
print(1+2+float(3)/4-5)
# Out:
# -1.25

# %% [markdown]
# # String conversions

# %% [markdown]
# - One can also use int() and float() to convert between strings and integers

# %% [markdown]
# - one will get an error if the string doesn't contain numeric characters

# %%
flod= '123'

# %%
type(flod)
# Out:
# str

# %%
print(sval+w)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11244/2446927185.py in <module>
# ----> 1 print(sval+w)
#
# NameError: name 'sval' is not defined

# %%
ival= int(flod)

# %%
type(ival)
# Out:
# int

# %%
print(ival + 1)
# Out:
# 124

# %% [markdown]
# ## Once we have defined a function,we can call or evoke it as many times as we want

# %% [markdown]
# ## Arguements

# %% [markdown]
# We use arguements so we can direct the function to do different kinds of works when we call it at different times

# %%
big = max('Hello world')

# %% [markdown]
# ## Return values

# %% [markdown]
# The return key is used for this

# %%
def greet():
# Out:
#   File "C:\Users\User\AppData\Local\Temp/ipykernel_11244/2262657367.py", line 1
#     def greet():
#                 ^
# IndentationError: expected an indented block
