# %% [markdown]
# # Importing data

# %% [markdown]
#  - This is the process of loading and reading data into python from various resources.

# %% [markdown]
# ### Two important properties

# %% [markdown]
# Format- This is the way data is encoded.We have various formats:CSV,json,xlsx,hdf
# #### CSV- Comma Separated Values

# %% [markdown]
# ## Printing the data frame in python

# %% [markdown]
# - df prints the entire data frame
# - df.head(n) to show the first n rows of data frame
# - df.tail(n) shows the bottom n rows of data frame

# %% [markdown]
# ## Exporting to a different format in python

# %%
 Data format          Read                              save

# %%
CSV                   pd.read_csv()                      df.to_csv()

# %%
json                  pd.read_json()                      df.to_json()

# %%
excel                 pd.read_excel()                      df.to_excel()

# %%
sql                   pd.read_sql()                         df.to_sql()
