# %% [markdown]
# ## Dictionaries

# %% [markdown]
# - the most powerful data collection

# %% [markdown]
# - allows us to do fast data base

# %% [markdown]
# - A 'bag' of values each with its own label

# %% [markdown]
# ## Creating dictionaries

# %%
d1 ={}
print(d1)
print(type(d1))
# Out:
# {}
# <class 'dict'>

# %% [markdown]
# ## Adding elements

# %%
d ={}
d[0] ="welcome"
print(d)
# Out:
# {0: 'welcome'}

# %%
d[1] =("How","are","you")
print(d)
# Out:
# {0: 'welcome', 1: ('How', 'are', 'you')}

# %%
d["name"]="sam"
print(d)
# Out:
# {0: 'welcome', 1: ('How', 'are', 'you'), 'name': 'sam'}

# %%
d["name"]={"first":"sam","last":"crew"}
print(d)
# Out:
# {0: 'welcome', 1: ('How', 'are', 'you'), 'name': {'first': 'sam', 'last': 'crew'}}

# %% [markdown]
# ## Accessing elements

# %%
print(d)
# Out:
# {0: 'welcome', 1: ('How', 'are', 'you'), 'name': {'first': 'sam', 'last': 'crew'}}

# %%
print(d["name"])
# Out:
# {'first': 'sam', 'last': 'crew'}

# %%
print(d["name"]["first"])
# Out:
# sam

# %%
print(d.get(1))
# Out:
# ('How', 'are', 'you')

# %% [markdown]
# - # Deleting elements

# %%
print(d)
# Out:
# {0: 'welcome', 1: ('How', 'are', 'you'), 'name': {'first': 'sam', 'last': 'crew'}}

# %%
d.pop(0)
# Out:
# 'welcome'

# %%
print(d)
# Out:
# {1: ('How', 'are', 'you'), 'name': {'first': 'sam', 'last': 'crew'}}

# %%
d.popitem()
# Out:
# ('name', {'first': 'sam', 'last': 'crew'})

# %%
print(d)
# Out:
# {1: ('How', 'are', 'you')}

# %% [markdown]
# ## example 1

# %%
Purse = dict()

# %%
Purse['candy']
Purse['money']
Purse['tissues']
print(Purse)
# Out:
# {'tissues': 75, 'money': 12, 'candy': 5}

# %%
print(Purse['candy'])
# Out:
# 3

# %%
Purse['candy'] =Purse['candy'] + 2

# %%
print(Purse)
# Out:
# {'tissues': 75, 'money': 12, 'candy': 5}

# %% [markdown]
# ## comparing lists and values

# %% [markdown]
# - Dictionaries are like lists except that they use keys instead of numbers to look up values

# %% [markdown]
# - Lists                                                                - Dictionaries

# %%
ddd= dict()

# %%
ddd['age'] = 21

# %%
ddd['course'] = 182
print(ddd)
# Out:
# {'age': 21, 'course': 182}

# %%
ddd['age'] = 23

# %%
print(ddd)
# Out:
# {'age': 23, 'course': 182}

# %% [markdown]
# ## Dictionary literals

# %% [markdown]
# - They use curly braces and have a list of key:value pairs

# %%
jjj = { 'Chuck':1,'Fred':42,'Jan':100 }

# %%
print(jjj)
# Out:
# {'Chuck': 1, 'Fred': 42, 'Jan': 100}

# %%
ooo= {}

# %%
print(ooo)
# Out:
# {}

# %% [markdown]
# ## Counting how often we see something

# %%
ccc = dict()

# %%
ccc['csev'] = 1

# %%
ccc['cwen'] = 1
print(ccc)
# Out:
# {'csev': 1, 'cwen': 1}

# %%
ccc['cwen'] = ccc['cwen'] + 1

# %%
print(ccc)
# Out:
# {'csev': 1, 'cwen': 2}

# %% [markdown]
# ## A key that doesn't exist

# %%
ccc= dict()

# %%
print(ccc['csev']
# Out:
#   File "C:\Users\User\AppData\Local\Temp/ipykernel_7060/1704976359.py", line 1
#     print(ccc['csev']
#                      ^
# SyntaxError: unexpected EOF while parsing

# %%
'csev' in ccc
# Out:
# False

# %% [markdown]
# - ## Sets in python

# %% [markdown]
# - Set is an unordered collection of unique elements

# %%
s= set([1,2,3,4])

# %%
print(s)
print (type(s))
# Out:
# {1, 2, 3, 4}
# <class 'set'>

# %%
s,dd("a")
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7060/1284999665.py in <module>
# ----> 1 s,dd("a")
#       2 print(s)
#
# NameError: name 'dd' is not defined
