# %% [markdown]
# ## What is pandas

# %% [markdown]
# # Pandas,as the anconda does tell us,offers us"High-performance,easy-to-use data structures and data analysis tools

# %%
import pandas as pd

# %%
heart = pd.read_csv("C:\\Users\\User\\Desktop\\data  science bootcamp\\Dataset\\heart.csv")
## Return the first number of read assignment
heart.head()

#heart.columns
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heart.values
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %%
heart.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
# Return a random sample of items from an axis of object
heart.sample(8)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 258   62    0   0       150   244    0        1      154      1      1.4
# 95    53    1   0       142   226    0        0      111      1      0.0
# 13    64    1   3       110   211    0        0      144      1      1.8
# 132   42    1   1       120   295    0        1      162      0      0.0
# 175   40    1   0       110   167    0        0      114      1      2.0
# 2     41    0   1       130   204    0        0      172      0      1.4
# 199   65    1   0       110   248    0        0      158      0      0.6
# 168   63    1   0       130   254    0        0      147      0      1.4
#
#      slope  ca  thal  target
# 258      1   0     2       0
# 95       2   0     3       1
# 13       1   0     2       1
# 132      2   0     2       1
# 175      1   0     3       0
# 2        2   0     2       1
# 199      2   2     1       0
# 168      1   1     3       0

# %%
# Describe() is used to view basic statistical details like percentile,mean,std etc
heart.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart['age'].max()
# Out:
# 77

# %% [markdown]
# ### Adding to a data frame

# %%
extra_rows= {'age':[40,30],'sex':[1,0],'cp':[0,0],'trestbps':[120,130],
             'chol':[240,200],
             'fbs':[0,0],'restecg':[1,0],'chalach':[120,122],'exang':[0,1],
             'oldpeak':[0.1,1.0],'slope':[1,1],'ca':[0,1],'thal':[2,3],
             'target':[0,0]}
extra_rows
# Out:
# {'age': [40, 30],
#  'sex': [1, 0],
#  'cp': [0, 0],
#  'trestbps': [120, 130],
#  'chol': [240, 200],
#  'fbs': [0, 0],
#  'restecg': [1, 0],
#  'chalach': [120, 122],
#  'exang': [0, 1],
#  'oldpeak': [0.1, 1.0],
#  'slope': [1, 1],
#  'ca': [0, 1],
#  'thal': [2, 3],
#  'target': [0, 0]}

# %%
# let's first turn this into a data frame
# we can use the from_dict() method

extra = pd.DataFrame().from_dict(extra-rows)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5636/3361483152.py in <module>
#       2 # we can use the from_dict() method
#       3
# ----> 4 extra = pd.DataFrame().from_dict(extra-rows)
#
# NameError: name 'extra' is not defined

# %%
# Now we just need to concatenate the two data frames together
heart_augmented = pd.concat([heart,extras],ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5636/1996474169.py in <module>
#       1 # Now we just need to concatenate the two data frames together
# ----> 2 heart_augmented = pd.concat([heart,extras],ignore_index = True)
#
# NameError: name 'extras' is not defined
